# %%
import pandas as pd
import matplotlib.pyplot as plt
# downloaded data using :https://data.cityofchicago.org/browse?browseSearch=311&view_type=rich&q=311&sortBy=relevance&utf8=%E2%9C%93

# %%
graffitti = pd.read_csv("Graffiti_Removal.csv")
pot_holes = pd.read_csv("Pot_Holes_Reported.csv")
sanitation = pd.read_csv("Sanitation_Code_Complaints.csv")
building = pd.read_csv("Vacant_and_Abandoned_Buildings_Reported.csv")
orig_col = ["Creation Date", "Status", "Completion Date", "Service Request Number", "Type of Service Request", "Street Address", "ZIP Code", "X Coordinate", "Y Coordinate", "Ward", "Police District", "Community Area", "Latitude", "Longitude", "Location"]

# %%
#graffitti.columns = [col_name.title() for col_name in graffitti.columns]
#pot_holes.columns = [col_name.title() for col_name in pot_holes.columns]
#sanitation.columns = [col_name.title() for col_name in sanitation.columns]
#building.columns = [col_name.title() for col_name in building.columns]
#building.rename(columns={"Zip Code": "ZIP Code", 'Service Request Type': 'Type Of Service Request', 'Date Service Request Was Received': 'Creation Date'}, inplace=True)

# %%
graffitti = graffitti[["Creation Date", "Completion Date", "Service Request Number", "Type of Service Request", "What Type of Surface is the Graffiti on?", "Street Address", "ZIP Code", "X Coordinate", "Y Coordinate", "Ward", "Police District", "Community Area", "Latitude", "Longitude", "Location"]]
pot_holes = pot_holes[["CREATION DATE", "COMPLETION DATE", "SERVICE REQUEST NUMBER", "TYPE OF SERVICE REQUEST", "STREET ADDRESS", "ZIP", "X COORDINATE", "Y COORDINATE", "Ward", "Police District", "Community Area", "LATITUDE", "LONGITUDE", "LOCATION"]]
pot_holes.columns = ["Creation Date", "Completion Date", "Service Request Number", "Type of Service Request", "Street Address", "ZIP Code", "X Coordinate", "Y Coordinate", "Ward", "Police District", "Community Area", "Latitude", "Longitude", "Location"]
sanitation = sanitation[["Creation Date", "Service Request Number", "Type of Service Request", "What is the Nature of this Code Violation?", "Street Address", "ZIP Code", "X Coordinate", "Y Coordinate", "Ward", "Police District", "Community Area", "Latitude", "Longitude", "Location"]]
building.columns = [col_name.title() for col_name in building.columns]
building.rename(columns={"Zip Code": "ZIP Code", 'Service Request Type': 'Type of Service Request', 'Date Service Request Was Received': 'Creation Date'}, inplace=True)
building["Street Address"] = building["Address Street Number"].map(str) + " " + building["Address Street Direction"] + " " + building["Address Street Name"] + " " + building["Address Street Suffix"]
building = building[["Creation Date", "Service Request Number", "Type of Service Request", "Street Address", "ZIP Code", "X Coordinate", "Y Coordinate", "Ward", "Police District", "Community Area", "Latitude", "Longitude", "Location"]]

# %%
combined_311 = graffitti.append([pot_holes, sanitation, building])
combined_311["Response Time"] = pd.to_datetime(combined_311["Completion Date"])- pd.to_datetime(combined_311["Creation Date"])

# %%
combined_311.to_csv("Result1.csv")
combined_311
# Out:
#       Community Area Completion Date Creation Date   Latitude  \
# 0               16.0      04/01/2016    04/01/2016  41.968020
# 1               16.0      04/01/2016    04/01/2016  41.968021
# 2               16.0      04/01/2016    04/01/2016  41.968022
# 3               16.0      04/01/2016    04/01/2016  41.968023
# 4               14.0      04/01/2016    04/01/2016  41.968240
# 4741   (41.75975444208117, -87.61515313188558) -87.615153              3.0
# 4742   (41.67754406657209, -87.61542402951578) -87.615424              5.0
# 4743   (41.87573809779663, -87.75619374553764) -87.756194             15.0
# 4744  (41.859526747409966, -87.65342670141472) -87.653427             12.0
# 4745   (41.70655797799014, -87.61618735519474) -87.616187              5.0
# 4746   (41.84170557507647, -87.72569674041564) -87.725697             10.0
# 4747   (41.825448219541364, -87.6276272480064) -87.627627              2.0
# 4748   (41.72804875898266, -87.62276882062083) -87.622769              6.0
# 4749  (41.796709780783125, -87.64767922604113) -87.647679              9.0
#
#      Service Request Number                      Street Address  \
# 0               16-02196950                 4407 W LAWRENCE AVE
# 1               16-02196966                 4405 W LAWRENCE AVE
# 2               16-02197022                 4403 W LAWRENCE AVE
# 3               16-02197024                 4401 W LAWRENCE AVE
# 4               16-02197026                 4406 W LAWRENCE AVE
# 5               16-02188698             9301 S STONY ISLAND AVE
# 6               16-02192880                   5708 S HAMLIN AVE
# 7               16-02192984               3807 S CALIFORNIA AVE
# 8               16-02181833                    1800 N DAMEN AVE
# 9               16-02181838                    1801 N DAMEN AVE
# 10              16-02181843                    1758 N DAMEN AVE
# 11              16-02181847                    1759 N DAMEN AVE
# 12              16-02181850                    1755 N DAMEN AVE
# 13              16-02181857                2741 N MILWAUKEE AVE
# 14              16-02181859                2749 N MILWAUKEE AVE
# 15              16-02181863                2748 N SPAULDING AVE
# 16              16-02181865                2746 N SPAULDING AVE
# 17              16-02181870                2744 N SPAULDING AVE
# 18              16-02181874                2742 N SPAULDING AVE
# 19              16-02181876                2740 N SPAULDING AVE
# 20              16-02181939                   4000 S ARCHER AVE
# 21              16-02181941                 4416 W DIVERSEY AVE
# 22              16-02181975                   4004 S ARCHER AVE
# 23              16-02181984               2200 N SACRAMENTO AVE
# 24              16-02182006                   3991 S ARCHER AVE
# 25              16-02182017                 2624 W DIVERSEY AVE
# 26              16-02182022                 2630 W DIVERSEY AVE
# 27              16-02182025                 2700 W DIVERSEY AVE
# 28              16-02182031                 2812 W DIVERSEY AVE
# 29              16-02182035                 2816 W DIVERSEY AVE
# ...                     ...                                 ...
# 4720            17-01807240                     5954 S LOWE AVE
# 4721            17-01807401                      215 W 111TH PL
# 4722            17-01808913                     1146 W 111TH PL
# 4723            17-01809199                      3546 W 62ND PL
# 4724            17-01809328                 7001 S EAST END AVE
# 4725            17-01815650                 5056 W AUGUSTA BLVD
# 4726            17-01815831                  9713 S JEFFERY AVE
# 4727            17-01821046               7212 S UNIVERSITY AVE
# 4728            17-01821428                      151 E 120TH ST
# 4729            17-01835374                 10762 S LONGWOOD DR
# 4730            17-01835804                8401 S MARQUETTE AVE
# 4731            17-01821924                 6811 S CARPENTER ST
# 4732            17-01823534                       628 E 92ND PL
# 4733            17-01823898                   11717 S MORGAN ST
# 4734            17-01825071                  9721 S OGLESBY AVE
# 4735            17-01826766                  6520 S STEWART AVE
# 4736            17-01827900                  7318 S ABERDEEN ST
# 4737            17-01828192                   6831 S PAULINA ST
# 4738            17-01829075                 10137 S EMERALD AVE
# 4                             Metal - Painted
# 5                           Brick - Unpainted
# 6                            Wood - Unpainted
# 7                             Aluminum Siding
# 8        Cement (Sidewalk, Alley, Wall, Curb)
# 9        Cement (Sidewalk, Alley, Wall, Curb)
# 10       Cement (Sidewalk, Alley, Wall, Curb)
# 11       Cement (Sidewalk, Alley, Wall, Curb)
# 12                          Metal - Unpainted
# 13                          Brick - Unpainted
# 14                          Brick - Unpainted
# 15                          Brick - Unpainted
# 16                          Brick - Unpainted
# 17                          Brick - Unpainted
# 18                          Brick - Unpainted
# 19                          Brick - Unpainted
# 20                             Wood - Painted
# 21                            Brick - Painted
# 22                            Metal - Painted
# 23                            Brick - Painted
# 24                            Brick - Painted
# 25                            Brick - Painted
# 26                            Brick - Painted
# 27                            Brick - Painted
# 28                            Brick - Painted
# 29                            Brick - Painted
# ...                                       ...
# 4720                                      NaN
# 4721                                      NaN
# 4722                                      NaN
# 4723                                      NaN
# 4724                                      NaN
# 4725                                      NaN
# 4726                                      NaN
# 4727                                      NaN
# 4728                                      NaN
# 4729                                      NaN
# 4730                                      NaN
# 4731                                      NaN
# 4732                                      NaN
# 4733                                      NaN
# 4734                                      NaN
# 4735                                      NaN
# 4736                                      NaN
# 4737                                      NaN
# 4738                                      NaN
# 4739                                      NaN
# 4740                                      NaN
# 4741                                      NaN
# 4742                                      NaN
# 4743                                      NaN
# 4744                                      NaN
# 4745                                      NaN
# 4746                                      NaN
# 4747                                      NaN
# 4748                                      NaN
# 4749                                      NaN
#
#      What is the Nature of this Code Violation?  X Coordinate  Y Coordinate  \
# 0                                           NaN  1.146093e+06  1.931539e+06
# 1                                           NaN  1.146117e+06  1.931539e+06
# 2                                           NaN  1.146141e+06  1.931540e+06
# 3                                           NaN  1.146165e+06  1.931540e+06
# 4                                           NaN  1.146105e+06  1.931539e+06
# 5                                           NaN  1.188415e+06  1.843620e+06
# 6                                           NaN  1.152015e+06  1.866455e+06
# 7                                           NaN  1.158328e+06  1.879251e+06
# 8                                           NaN  1.162739e+06  1.912102e+06
# 9                                           NaN  1.162739e+06  1.912105e+06
# 10                                          NaN  1.162743e+06  1.911923e+06
# 11                                          NaN  1.162744e+06  1.911871e+06
# 12                                          NaN  1.162744e+06  1.911892e+06
# 13                                          NaN  1.153729e+06  1.918044e+06
# 14                                          NaN  1.153672e+06  1.918089e+06
# 15                                          NaN  1.153762e+06  1.918153e+06
# 16                                          NaN  1.153757e+06  1.918142e+06
# 17                                          NaN  1.153752e+06  1.918132e+06
# 18                                          NaN  1.153747e+06  1.918121e+06
# 19                                          NaN  1.153741e+06  1.918110e+06
# 20                                          NaN  1.158820e+06  1.878035e+06
# 21                                          NaN  1.146384e+06  1.918247e+06
# 22                                          NaN  1.158791e+06  1.878011e+06
# 23                                          NaN  1.156008e+06  1.914618e+06
# 24                                          NaN  1.158867e+06  1.878074e+06
# 25                                          NaN  1.158292e+06  1.918506e+06
# 26                                          NaN  1.158238e+06  1.918505e+06
# 27                                          NaN  1.157954e+06  1.918498e+06
# 28                                          NaN  1.157091e+06  1.918485e+06
# 29                                          NaN  1.157045e+06  1.918484e+06
# ...                                         ...           ...           ...
# 4720                                        NaN  1.172997e+06  1.865280e+06
# 4721                                        NaN  1.176824e+06  1.831005e+06
# 4722                                        NaN  1.170671e+06  1.830857e+06
# 4723                                        NaN  1.153848e+06  1.862949e+06
# 4724                                        NaN  1.188987e+06  1.858900e+06
# 4725                                        NaN  1.142385e+06  1.906181e+06
# 4726                                        NaN  1.191209e+06  1.840957e+06
# 4727                                        NaN  1.185129e+06  1.857425e+06
# 4728                                        NaN  1.179377e+06  1.825427e+06
# 4729                                        NaN  1.165065e+06  1.833251e+06
# 4730                                        NaN  1.195624e+06  1.849791e+06
# 4731                                        NaN  1.170488e+06  1.859651e+06
# 4732                                        NaN  1.182046e+06  1.843779e+06
# 4733                                        NaN  1.171764e+06  1.827121e+06
# 4734                                        NaN  1.193674e+06  1.840771e+06
# 4735                                        NaN  1.174743e+06  1.861822e+06
# 4736                                        NaN  1.170249e+06  1.856281e+06
# 4737                                        NaN  1.166189e+06  1.859401e+06
# 4738                                        NaN  1.173097e+06  1.837637e+06
# 4739                                        NaN  1.158417e+06  1.864344e+06
# 4740                                        NaN  1.166284e+06  1.856013e+06
# 4741                                        NaN  1.180194e+06  1.855863e+06
# 4742                                        NaN  1.180370e+06  1.825906e+06
# 4743                                        NaN  1.141429e+06  1.897837e+06
# 4744                                        NaN  1.169464e+06  1.892135e+06
# 4745                                        NaN  1.180073e+06  1.836477e+06
# 4746                                        NaN  1.149822e+06  1.885493e+06
# 4747                                        NaN  1.176594e+06  1.879774e+06
# 4748                                        NaN  1.178211e+06  1.844293e+06
# 4749                                        NaN  1.171212e+06  1.869257e+06
#
#       ZIP Code  Response Time
# 0      60630.0         0 days
# 1      60630.0         0 days
# 2      60630.0         0 days
# 3      60630.0         0 days
# 4      60630.0         0 days
# 5      60617.0         0 days
# 6      60629.0         0 days
# 7      60632.0         0 days
# 8      60647.0         0 days
# 9      60647.0         0 days
# 10     60647.0         0 days
# 11     60647.0         0 days
# 12     60647.0         0 days
# 13     60647.0         0 days
# 14     60647.0         0 days
# 15     60647.0         0 days
# 16     60647.0         0 days
# 17     60647.0         0 days
# 18     60647.0         0 days
# 19     60647.0         0 days
# 20     60632.0         0 days
# 21     60639.0         0 days
# 22     60632.0         0 days
# 23     60647.0         0 days
# 24     60632.0         0 days
# 25     60647.0         0 days
# 26     60647.0         0 days
# 27     60647.0         0 days
# 28     60647.0         0 days
# 29     60647.0         0 days
# ...        ...            ...
# 4720   60621.0            NaT
# 4721   60628.0            NaT
# 4722   60643.0            NaT
# 4723   60629.0            NaT
# 4724   60649.0            NaT
# 4725   60651.0            NaT
# 4726   60617.0            NaT
# 4727   60619.0            NaT
# 4728   60628.0            NaT
# 4729   60643.0            NaT
# 4730   60617.0            NaT
# 4731   60621.0            NaT
# 4732   60619.0            NaT
# 4733   60643.0            NaT
# 4734   60617.0            NaT
# 4735   60621.0            NaT
# 4736   60621.0            NaT
# 4737   60636.0            NaT
# 4738   60628.0            NaT
# 4739   60629.0            NaT
# 4740   60636.0            NaT
# 4741   60619.0            NaT
# 4742   60628.0            NaT
# 4743   60644.0            NaT
# 4744   60608.0            NaT
# 4745   60628.0            NaT
# 4746   60623.0            NaT
# 4747   60609.0            NaT
# 4748   60619.0            NaT
# 4749   60609.0            NaT
#
# [199756 rows x 17 columns]

# %%
#count_graffitti = graffitti.groupby(["What Type of Surface is the Graffiti on?"],axis = 0).count()["Creation Date"]
#count_graffitti_zip = graffitti.groupby(["What Type of Surface is the Graffiti on?", "ZIP Code"],axis = 0).count()["Creation Date"]

# %%
count_graffitti_zip = pd.pivot_table(graffitti, index = ["ZIP Code","What Type of Surface is the Graffiti on?"], values = ["Creation Date"], columns = ["Type of Service Request"], aggfunc = [len])
count_311_combined = pd.pivot_table(combined_311, index = ["Type of Service Request"], values = ["Creation Date"], aggfunc = [len])
count_graffitti = pd.pivot_table(graffitti, index = ["What Type of Surface is the Graffiti on?"], values = ["Creation Date"], columns = ["Type of Service Request"], aggfunc = [len])

# %%
combined_311["complaint_month"] = pd.DatetimeIndex(combined_311["Creation Date"]).month 
#count_311_combined = pd.pivot_table(combined_311, index = ["Type of Service Request", "complaint_month"], values = ["Creation Date"], aggfunc = [len])

# %%
count_311_combined = pd.pivot_table(combined_311, index = ["Ward"], columns = ["Type of Service Request"],values = ["Creation Date"], aggfunc = [len])

# %%
import numpy as np
count_311_combined = pd.pivot_table(combined_311, index = ["Ward"], columns = ["Type of Service Request"],values = ["Creation Date"], aggfunc = [len])
t = count_311_combined
l1 = plt.bar(np.arange(0,51), [x[0] for x in t[[0]].values.tolist()], width = 0.4
             , align='center',color = 'red', label = "Graffiti Removal" )
l2 = plt.bar(np.arange(0,51)+0.5, [x[0] for x in t[[1]].values.tolist()], width = .5,align='center', color = 'blue', label = "Pothole in Street")
l3 = plt.bar(np.arange(0,51)+ 1, [x[0] for x in t[[2]].values.tolist()],  width = .5, align='center', color = 'green', label = "Sanitation Code Violation")
l4 = plt.bar(np.arange(0,51)+1.5, [x[0] for x in t[[3]].values.tolist()],  width = .5, align='center', color = 'yellow', label = "Vacant/Abandoned Building")
plt.xticks(range(51))
plt.legend(handles=[l1, l2, l3, l4], prop={'size':5})
plt.tight_layout()
plt.autoscale(tight=True)
plt.show()

# %%
len([x[0] for x in t[[0]].values.tolist()])
# Out:
# 51

# %%
t = count_311_combined
l1, = plt.plot(t[[0]], color = 'red', label = "Graffiti Removal" )
l2, = plt.plot(t[[1]], color = 'blue', label = "Pothole in Street")
l3, = plt.plot(t[[2]], color = 'green', label = "Sanitation Code Violation")
l4, = plt.plot(t[[3]], color = 'yellow', label = "Vacant/Abandoned Building")
plt.xticks(range(50), size = 'small')
plt.legend(prop={'size':5})
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
count_sanitation = sanitation["What is the Nature of this Code Violation?"].value_counts()
count_sanitation.plot("bar")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
count_sanitation_ward = combined_311.groupby(["Ward"],axis = 0).count()["Creation Date"]
count_sanitation_ward.plot("bar")

# %%
for i in range(0, len(df)):
    print(df.iloc[i]["Latitude"], df.iloc[i]['Longitude'])
# Out:
# 41.9680204661 -87.7382096132
# 41.9680213287 -87.7381277106
# 41.9680221912 -87.7380458081
# 41.9680232822 -87.7379631927
# 41.9682399756 -87.7382137642
# 41.725895797 -87.5848243152
# 41.7893312205 -87.7182979722
# 41.8243643762 -87.6945090495
# 41.9145594604 -87.6777000289
# 41.9144680515 -87.6774049056

# %%
########## Part 2 ####################

# %%
import urllib3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import urllib
import urllib3
import ast

# %%
req_data = combined_311[(combined_311["Type of Service Request"] == "Sanitation Code Violation")]
req_data_1 = req_data.pivot_table(index=['Location'], aggfunc='count')
req_data_1 = req_data_1.sort_values(by=['Creation Date'], ascending=False)[:10]
#y = req_data_2.index.tolist()
#vals = [ast.literal_eval(each) for each in y]
#df.loc[df['column_name'].isin(some_values)]
#req_data_1 = req_data[req_data['Location']==(41.9548460781068, -87.69949148880588)]

# %%
req_data_1
# Out:
#                                           Community Area  Completion Date  \
# Location
# (41.9548460781068, -87.69949148880588)                82                0
# (41.92733896999876, -87.64152891470731)               49                0
# (41.80775624733463, -87.73264438271458)               41                0
# (41.95455321973826, -87.69948225857972)               37                0
# (41.95448021145578, -87.69948004089855)               29                0
# (41.92754221311281, -87.6416483549574)                27                0
# (41.72486470577999, -87.62067425893234)               26                0
# (41.808896239600024, -87.73707839474409)              22                0
# (41.861743605791936, -87.71772542701335)              21                0
# (41.706890776913674, -87.64565659043554)              20                0
#
#                                           Creation Date  Latitude  Longitude  \
# Location
# (41.9548460781068, -87.69949148880588)               82        82         82
# (41.92733896999876, -87.64152891470731)              49        49         49
# (41.80775624733463, -87.73264438271458)              41        41         41
# (41.95455321973826, -87.69948225857972)              37        37         37
# (41.95448021145578, -87.69948004089855)              29        29         29
# (41.92754221311281, -87.6416483549574)               27        27         27
# (41.72486470577999, -87.62067425893234)              26        26         26
# (41.808896239600024, -87.73707839474409)             22        22         22
# (41.861743605791936, -87.71772542701335)             21        21         21
# (41.706890776913674, -87.64565659043554)             20        20         20
#
#                                           Police District  Response Time  \
# Location
# (41.9548460781068, -87.69949148880588)                 82              0
# (41.92733896999876, -87.64152891470731)                49              0
# (41.80775624733463, -87.73264438271458)                41              0
# (41.95455321973826, -87.69948225857972)                37              0
# (41.95448021145578, -87.69948004089855)                29              0
# (41.92754221311281, -87.6416483549574)                 27              0
# (41.72486470577999, -87.62067425893234)                26              0
# (41.808896239600024, -87.73707839474409)               22              0
# (41.861743605791936, -87.71772542701335)               21              0
# (41.706890776913674, -87.64565659043554)               20              0
#
#                                           Service Request Number  \
# Location
# (41.9548460781068, -87.69949148880588)                        82
# (41.92733896999876, -87.64152891470731)                       49
# (41.80775624733463, -87.73264438271458)                       41
# (41.95455321973826, -87.69948225857972)                       37
# (41.95448021145578, -87.69948004089855)                       29
# (41.92754221311281, -87.6416483549574)                        27
# (41.72486470577999, -87.62067425893234)                       26
# (41.808896239600024, -87.73707839474409)                      22
# (41.861743605791936, -87.71772542701335)                      21
# (41.706890776913674, -87.64565659043554)                      20
#
#                                           Street Address  \
# Location
# (41.9548460781068, -87.69949148880588)                82
# (41.92733896999876, -87.64152891470731)               49
# (41.80775624733463, -87.73264438271458)               41
# (41.95455321973826, -87.69948225857972)               37
# (41.95448021145578, -87.69948004089855)               29
# (41.92754221311281, -87.6416483549574)                27
# (41.72486470577999, -87.62067425893234)               26
# (41.808896239600024, -87.73707839474409)              22
# (41.861743605791936, -87.71772542701335)              21
# (41.706890776913674, -87.64565659043554)              20
#
#                                           Type of Service Request  Ward  \
# Location
# (41.9548460781068, -87.69949148880588)                         82    82
# (41.92733896999876, -87.64152891470731)                        49    49
# (41.80775624733463, -87.73264438271458)                        41    41
# (41.95455321973826, -87.69948225857972)                        37    37
# (41.95448021145578, -87.69948004089855)                        29    29
# (41.92754221311281, -87.6416483549574)                         27    27
# (41.72486470577999, -87.62067425893234)                        26    26
# (41.808896239600024, -87.73707839474409)                       22    22
# (41.861743605791936, -87.71772542701335)                       21    21
# (41.706890776913674, -87.64565659043554)                       20    20
#
#                                           What Type of Surface is the Graffiti on?  \
# Location
# (41.9548460781068, -87.69949148880588)                                           0
# (41.92733896999876, -87.64152891470731)                                          0
# (41.80775624733463, -87.73264438271458)                                          0
# (41.95455321973826, -87.69948225857972)                                          0
# (41.95448021145578, -87.69948004089855)                                          0
# (41.92754221311281, -87.6416483549574)                                           0
# (41.72486470577999, -87.62067425893234)                                          0
# (41.808896239600024, -87.73707839474409)                                         0
# (41.861743605791936, -87.71772542701335)                                         0
# (41.706890776913674, -87.64565659043554)                                         0
#
#                                           What is the Nature of this Code Violation?  \
# Location
# (41.9548460781068, -87.69949148880588)                                            81
# (41.92733896999876, -87.64152891470731)                                           49
# (41.80775624733463, -87.73264438271458)                                           38
# (41.95455321973826, -87.69948225857972)                                           37
# (41.95448021145578, -87.69948004089855)                                           29
# (41.92754221311281, -87.6416483549574)                                            27
# (41.72486470577999, -87.62067425893234)                                           26
# (41.808896239600024, -87.73707839474409)                                          20
# (41.861743605791936, -87.71772542701335)                                          21
# (41.706890776913674, -87.64565659043554)                                          20
#
#                                           X Coordinate  Y Coordinate  \
# Location
# (41.9548460781068, -87.69949148880588)              82            82
# (41.92733896999876, -87.64152891470731)             49            49
# (41.80775624733463, -87.73264438271458)             41            41
# (41.95455321973826, -87.69948225857972)             37            37
# (41.95448021145578, -87.69948004089855)             29            29
# (41.92754221311281, -87.6416483549574)              27            27
# (41.72486470577999, -87.62067425893234)             26            26
# (41.808896239600024, -87.73707839474409)            22            22
# (41.861743605791936, -87.71772542701335)            21            21
# (41.706890776913674, -87.64565659043554)            20            20
#
#                                           ZIP Code  complaint_month
# Location
# (41.9548460781068, -87.69949148880588)          82               82
# (41.92733896999876, -87.64152891470731)         49               49
# (41.80775624733463, -87.73264438271458)         41               41
# (41.95455321973826, -87.69948225857972)         37               37
# (41.95448021145578, -87.69948004089855)         29               29
# (41.92754221311281, -87.6416483549574)          27               27
# (41.72486470577999, -87.62067425893234)         26               26
# (41.808896239600024, -87.73707839474409)        22               22
# (41.861743605791936, -87.71772542701335)        21               21
# (41.706890776913674, -87.64565659043554)        20               20

# %%
apikey = "1b405de29a6fab983a2375f6aa4af12ff59082e5"
code_represents = {"B01002_001E": "age",  #median age
                    "B23025_002E": "employment_labor_force", #Number of persons, age 16 or older, in the labor force.,
                    "B23025_005E": "employment_unemployed", #Number of unemployed, age 16 or older, in the civilian labor force. 
                    "B19013_001E": "income", # Median household income in the past 12 months (in 2013 inflation-adjusted dollars).
                    "B19301_001E": "income_per_capita", #Per capita income in the past 12 months (in 2013 inflation-adjusted dollars).
                    "B01002_003E": "median_female_age", #Median age by sex (female).
                    "B01002_002E": "median_male_age", #Median age by sex (male).
                    "B01003_001E": "population", #Total population
                    "B17001_002E":  "poverty", #Number of persons whose income in the past 12 months is below the poverty level
                   }

# %%
def url_to_dic(address):
    pm = urllib3.PoolManager()
    html = pm.urlopen(url=address, method='GET').data
    soup = BeautifulSoup(html, 'lxml')
    data = soup.text
    dict_data = ast.literal_eval(data) 
    return dict_data

def augment(req_data, queries = code_represents):
    result_blockwise = {}
    for i in range(0, len(req_data)):
    #location = (req_data_1.iloc[i]["Latitude"], req_data_1.iloc[i]['Longitude'])
        location = ast.literal_eval(req_data.index[i])
        url1 = 'http://data.fcc.gov/api/block/find?format=json&latitude={}&longitude={}&showall=true'.format(location[0],location[1])
        dict_data = url_to_dic(url1)
        fips = dict_data['Block']['FIPS']
        state_id = fips[:2]
        county_id = fips[2:5]
        tract_id = fips[5:11]
        block_group_id = fips[11]
        for key,val in code_represents.items():
            query = key
            url2 = 'http://api.census.gov/data/2015/acs5?get={}&for=block+group:{}&in=state:{}+county:{}+tract:{}&key={}'.format(query,block_group_id,state_id,county_id,tract_id,apikey)
            pm = urllib3.PoolManager()
            html = pm.urlopen(url=url2, method='GET').data
            soup = BeautifulSoup(html, 'lxml')
            data = soup.text
            data = data.replace('null', "'null'")
            dict_data = ast.literal_eval(data)
            list_data = dict_data
            out = list_data[1][0]
            if val not in result_blockwise:
                result_blockwise[val] = []
            result_blockwise[val].append(out)
    return result_blockwise

# %%
    combined_311 = pd.read_csv("Result.csv")
    #For Sanitation
    req_data = combined_311[combined_311["Type of Service Request"] == "Sanitation Code Violation"]
    req_data_san = req_data.pivot_table(index=['Location'], aggfunc='count')
    req_data_san_top = req_data_san.sort_values(by=['Creation Date'], ascending=False)[:10]
    req_data_san_bottom = req_data_san.sort_values(by=['Creation Date'], ascending=False)[-10:]
    most_complaints_san = pd.DataFrame(augment(req_data_san_top))
    least_compaints_san = pd.DataFrame(augment(req_data_san_bottom))
   
    #For Vacant Building
    req_data = combined_311[combined_311["Type of Service Request"] == "Vacant/Abandoned Building"]
    req_data_bldg = req_data.pivot_table(index=['Location'], aggfunc='count')
    req_data_bldg_top = req_data_bldg.sort_values(by=['Creation Date'], ascending=False)[:10]
    req_data_bldg_bottom = req_data_san.sort_values(by=['Creation Date'], ascending=False)[-10:]
    most_complaints_bldg = pd.DataFrame(augment(req_data_bldg_top))
    least_compaints_bldg = pd.DataFrame(augment(req_data_bldg_bottom))
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,12,13,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len([float(x) for x in most_complaints_san['age'].values.tolist()])
# Out:
# 10

# %%
#Cook County
def cook_county(queries = code_represents):

    result_blockwise = {}
    for key,val in code_represents.items():
        query = key
        url2 = 'http://api.census.gov/data/2015/acs5?get={}&for=county:031&in=state:17&key={}'.format(query,apikey)
        pm = urllib3.PoolManager()
        html = pm.urlopen(url=url2, method='GET').data
        soup = BeautifulSoup(html, 'lxml')
        data = soup.text
        data = data.replace('null', "'null'")
        dict_data = ast.literal_eval(data)
        list_data = dict_data
        out = list_data[1][0]
        if val not in result_blockwise:
            result_blockwise[val] = []
        result_blockwise[val].append(out)
    return result_blockwise
# Out:
# {'median_female_age': ['37.1'], 'employment_unemployed': ['296577'], 'median_male_age': ['34.7'], 'income_per_capita': ['31013'], 'income': ['55251'], 'poverty': ['879499'], 'employment_labor_force': ['2761294'], 'population': ['5236393'], 'age': ['35.9']}

# %%
cook_county_data = cook_county()
# Out:
# {'median_female_age': ['37.1'], 'employment_unemployed': ['296577'], 'median_male_age': ['34.7'], 'income_per_capita': ['31013'], 'income': ['55251'], 'poverty': ['879499'], 'employment_labor_force': ['2761294'], 'population': ['5236393'], 'age': ['35.9']}

# %%
l1 =plt.bar(np.arange(0,10), [float(x) for x in most_complaints_san['employment_unemployed'].values.tolist()], width = .4, color = 'red', label = "max_compaints" )
l2 = plt.bar(np.arange(0,10)+ 0.5, [float(x) for x in least_compaints_san['employment_unemployed'].values.tolist()], width = .4 , color = 'blue', label = "min_complaints")
plt.axhline(y = float(cook_county_data["employment_unemployed"][0])/100000)
plt.xticks(range(11))
plt.legend(prop={'size':5})
plt.tight_layout()
plt.xlabel("for max complaints 10 = min, for min complaints 10 = min")
plt.ylabel("Employment_unemployed")
plt.title('Sanitation Complaints per Capita Income')
plt.show()

# %%
l1 =plt.bar(np.arange(0,10), [float(x) for x in most_complaints_bldg['employment_unemployed'].values.tolist()], width = .4, color = 'red', label = "max_compaints" )
l2 = plt.bar(np.arange(0,10)+ 0.5, [float(x) for x in least_compaints_bldg['employment_unemployed'].values.tolist()], width = .4 , color = 'blue', label = "min_complaints")
plt.axhline(y = float(cook_county_data["employment_unemployed"][0])/10000)
plt.xticks(range(11))
plt.legend(prop={'size':5})
plt.tight_layout()
plt.xlabel("for max complaints 10 = min, for min complaints 10 = min")
plt.ylabel("Employment_unemployed")
plt.title('Vacant/Abandon Complaints per Capita Income')
plt.show()

# %%
################# Question 3 ###################

# %%
#data for 7500 S Wolcott Ave
lat = 41.757380
lon = -87.671264
ward = 17
ward_wise_data = combined_311.loc[:,['Type of Service Request','Ward']]
ward_clustered = pd.crosstab(ward_wise_data.loc[:,'Type of Service Request'], ward_wise_data.loc[:,'Ward'], margins=True)
ward_clustered[17]
# Out:
# Type of Service Request
# Graffiti Removal              894
# Pothole in Street             889
# Sanitation Code Violation     563
# Vacant/Abandoned Building     342
# All                          2688
# Name: 17.0, dtype: int64

# %%
lawndale = combined_311[combined_311["Street Address"].str.contains("LAWNDALE")==True]
count_lawndale = lawndale.groupby(["Type of Service Request"]).count()["Creation Date"]
ward_clustered[46] #ward 46 is for uptown
#uptown = combined_311[combined_311["Street Address"].str.contains("UPTOWN")==True]
#count_uptown = uptown.groupby(["Type of Service Request"]).count()["Creation Date"]
count_lawndale
count_uptown
# Out:
# Series([], Name: Creation Date, dtype: int64)
